# %%
import pandas as pd

# %%
df = pd.read_csv ("Space_Corrected.csv")
df
# Out:
#       Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1
# count  4324.000000   4324.000000
# mean   2161.500000   2161.500000
# std    1248.375611   1248.375611
# min       0.000000      0.000000
# 25%    1080.750000   1080.750000
# 50%    2161.500000   2161.500000
# 75%    3242.250000   3242.250000
# max    4323.000000   4323.000000

# %%
df['Company Name']
# Out:
# 0          SpaceX
# 1            CASC
# 2          SpaceX
# 3       Roscosmos
# 4             ULA
#           ...
# 4319      US Navy
# 4320         AMBA
# 4321      US Navy
# 4322    RVSN USSR
# 4323    RVSN USSR
# Name: Company Name, Length: 4324, dtype: object

# %%
df.set_index('Company Name')
# Out:
#               Unnamed: 0  Unnamed: 0.1  \
# Company Name
# SpaceX                 0             0
# CASC                   1             1
# SpaceX                 2             2
# Roscosmos              3             3
# ULA                    4             4
# ...                  ...           ...
# US Navy             4319          4319
# AMBA                4320          4320
# US Navy             4321          4321
# RVSN USSR           4322          4322
# RVSN USSR           4323          4323
#
#                                                        Location  \
# Company Name
# SpaceX               LC-39A, Kennedy Space Center, Florida, USA
# CASC          Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# SpaceX                            Pad A, Boca Chica, Texas, USA
# Roscosmos          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# ULA                    SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                         ...
# ...

# %%
g = df.groupby("Company Name")
g

# %%
df['Location'].max()
# Out:
# 'Xichang Satellite Launch Center, China'

# %%
for Company, data in g:
    print("Company Name: ",Company)
    print("\n")
    print ("data: ", data)
# Out:
# Company Name:  AEB
#
#
# data:        Unnamed: 0  Unnamed: 0.1 Company Name  \
# 1032        1032          1032          AEB
# 1221        1221          1221          AEB
# 1354        1354          1354          AEB
#
#                                                Location  \
# 1032  VLS Pad, Alc?›ntara Launch Center, Maranh?œo, ...
# 1221  VLS Pad, Alc?›ntara Launch Center, Maranh?œo, ...
# 1354  VLS Pad, Alc?›ntara Launch Center, Maranh?œo, ...
#
#                            Datum                 Detail Status Rocket  Rocket  \
# 1032            Mon Aug 25, 2003  VLS-1 | SATEC, UNOSAT  StatusActive     NaN
# 1221  Sat Dec 11, 1999 19:40 UTC         VLS-1 | SACI-2  StatusActive     NaN
# 1354            Sun Nov 02, 1997         VLS-1 | SCD-2A  StatusActive     NaN
#
#          Status Mission
# 1032  Prelaunch Failure
# 1221            Failure
# 1354            Failure
# Company Name:  AMBA
#
#
# data:        Unnamed: 0  Unnamed: 0.1 Company Name  \
# ...

# %%
melted = pd.melt(df, id_vars=["Company Name"], var_name='Detail', value_name='Status Rocket')
melted
# Out:
#       Company Name          Detail Status Rocket
# 0           SpaceX      Unnamed: 0             0
# 1             CASC      Unnamed: 0             1
# 2           SpaceX      Unnamed: 0             2
# 3        Roscosmos      Unnamed: 0             3
# 4              ULA      Unnamed: 0             4
# ...            ...             ...           ...
# 34587      US Navy  Status Mission       Failure
# 34588         AMBA  Status Mission       Success
# 34589      US Navy  Status Mission       Failure
# 34590    RVSN USSR  Status Mission       Success
# 34591    RVSN USSR  Status Mission       Success
#
# [34592 rows x 3 columns]

# %%
df[0:3001]
# Out:
#       Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 2996        2996          2996    RVSN USSR
# 2997        2997          2997    RVSN USSR
# 2998        2998          2998          ASI
# 2999        2999          2999    RVSN USSR
# 3000        3000          3000    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
df[['Company Name','Detail','Status Rocket','Status Mission']]
# Out:
#      Company Name                                        Detail  \
# 0          SpaceX  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1            CASC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2          SpaceX            Starship Prototype | 150 Meter Hop
# 3       Roscosmos  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4             ULA                    Atlas V 541 | Perseverance
# ...           ...                                           ...
# 4319      US Navy                     Vanguard | Vanguard TV3BU
# 4320         AMBA                           Juno I | Explorer 1
# 4321      US Navy                       Vanguard | Vanguard TV3
# 4322    RVSN USSR                    Sputnik 8K71PS | Sputnik-2
# 4323    RVSN USSR                    Sputnik 8K71PS | Sputnik-1
#
#       Status Rocket Status Mission
# 0      StatusActive        Success
# 1      StatusActive        Success
# 2      StatusActive        Success
# 3      StatusActive        Success
# ...

# %%
df['Company Name'][df['Status Mission'] == 'Success']
# Out:
# 0          SpaceX
# 1            CASC
# 2          SpaceX
# 3       Roscosmos
# 4             ULA
#           ...
# 4316         AMBA
# 4317      US Navy
# 4320         AMBA
# 4322    RVSN USSR
# 4323    RVSN USSR
# Name: Company Name, Length: 3879, dtype: object

# %%
df = pd.read_csv("Space_Corrected.csv", na_values=["NaN",0])
df
# Out:
#       Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0            NaN           NaN       SpaceX
# 1            1.0           1.0         CASC
# 2            2.0           2.0       SpaceX
# 3            3.0           3.0    Roscosmos
# 4            4.0           4.0          ULA
# ...          ...           ...          ...
# 4319      4319.0        4319.0      US Navy
# 4320      4320.0        4320.0         AMBA
# 4321      4321.0        4321.0      US Navy
# 4322      4322.0        4322.0    RVSN USSR
# 4323      4323.0        4323.0    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
df.set_index('Company Name')
# Out:
#               Unnamed: 0  Unnamed: 0.1  \
# Company Name
# SpaceX               NaN           NaN
# CASC                 1.0           1.0
# SpaceX               2.0           2.0
# Roscosmos            3.0           3.0
# ULA                  4.0           4.0
# ...                  ...           ...
# US Navy           4319.0        4319.0
# AMBA              4320.0        4320.0
# US Navy           4321.0        4321.0
# RVSN USSR         4322.0        4322.0
# RVSN USSR         4323.0        4323.0
#
#                                                        Location  \
# Company Name
# SpaceX               LC-39A, Kennedy Space Center, Florida, USA
# CASC          Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# SpaceX                            Pad A, Boca Chica, Texas, USA
# Roscosmos          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# ULA                    SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                         ...
# ...

# %%
df = pd.read_csv("Space_Corrected.csv",  na_values={
        'Rocket': [0],
        
    })
df
# Out:
#       Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
df[0:15]
# Out:
#     Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0            0             0       SpaceX
# 1            1             1         CASC
# 2            2             2       SpaceX
# 3            3             3    Roscosmos
# 4            4             4          ULA
# 5            5             5         CASC
# 6            6             6    Roscosmos
# 7            7             7         CASC
# 8            8             8       SpaceX
# 9            9             9         JAXA
# 10          10            10     Northrop
# 11          11            11       ExPace
# 12          12            12         CASC
# 13          13            13          IAI
# 14          14            14         CASC
#
#                                              Location  \
# 0          LC-39A, Kennedy Space Center, Florida, USA
# 1   Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                       Pad A, Boca Chica, Texas, USA
# 3        Site 200/39, Baikonur Cosmodrome, Kazakhstan
# ...
